// %%
# Step 1: Upload the File
from google.colab import files
uploaded = files.upload()

# Step 2: Install and Import Libraries
!pip install pandas openpyxl matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
file_path = 'important of borkum.xlsx'  # replace with your file path
df = pd.read_excel(file_path)

# Display the data to verify
print(df)

# Assuming your data is in the first sheet and the relevant columns are named 'Category' and 'Value'
categories = ['tourist', 'home', 'patient', 'family', 'work', 'living', 'others', 'interest']
values = [1, 2, 3, 4, 5, 6, 7, 8]

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Categories')
plt.show()

# Display the data to verify
print(df)

# Assuming your data is in the first sheet and the relevant columns are named 'Category' and 'Value'
categories = ['tourist', 'home', 'patient', 'family', 'work', 'living', 'others', 'interest']
values = [1, 2, 3, 4, 5, 6, 7, 8]

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Categories')
plt.show()


#which features most significantly impact of sustainability attitudes
#Extract columns related to sustainability attitudes
sustainability_columns = [
    'NA02_01', 'NA02_02', 'NA02_03', 'NA02_04', 'NA02_05', 'NA02_06', 'NA02_07', 'NA02_08', 'NA02_09', 'NA02_10'
]

# Filter the dataframe to include only the relevant columns
sustainability_data = df[sustainability_columns]

# Compute the mean value of each column to determine the significance
sustainability_means = sustainability_data.mean().sort_values(ascending=False)

# Plot the mean values using a horizontal bar chart
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(sustainability_means.index, sustainability_means.values, color='skyblue')
plt.xlabel('Mean Value')
plt.title('Significance of Features on Sustainability Attitudes')
plt.gca().invert_yaxis()  # Highest values at the top
plt.show()

#what are the age and gender distributions of visitors to Borkum. use histogram


# Based on the analysis, the columns VB11 and VB08 could be related to gender.
# We will try using VB11 for the gender distribution analysis.

gender_data = df['VB11']

# Plot histograms for age and gender distributions
fig, axs = plt.subplots(2, 1, figsize=(10, 8))
# Based on the analysis, the columns VB11 and VB08 could be related to gender.
# We will try using VB11 for the gender distribution analysis.

gender_data = df['VB11']

# Plot histograms for age and gender distributions
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Age distribution
axs[0].hist(age_data.dropna(), bins=20, color='skyblue', edgecolor='black')
axs[0].set_title('Age Distribution of Borkum Visitors')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Frequency')

# Gender distribution
gender_counts = gender_data.dropna().value_counts()
axs[1].bar(gender_counts.index, gender_counts.values, color='lightgreen', edgecolor='black')
axs[1].set_title('Gender Distribution of Borkum Visitors')
axs[1].set_xticks(gender_counts.index)
axs[1].set_xticklabels(['Male', 'Female', 'Diverse'])
axs[1].set_xlabel('Gender')
axs[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()


# Age distribution
axs[0].hist(age_data.dropna(), bins=20, color='skyblue', edgecolor='black')
axs[0].set_title('Age Distribution of Borkum Visitors')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Frequency')

# Gender distribution
gender_counts = gender_data.dropna().value_counts()
axs[1].bar(gender_counts.index, gender_counts.values, color='lightgreen', edgecolor='black')
axs[1].set_title('Gender Distribution of Borkum Visitors')
axs[1].set_xticks(gender_counts.index)
axs[1].set_xticklabels(['Male', 'Female', 'Diverse'])
axs[1].set_xlabel('Gender')
axs[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
// Out:
// mambajs 0.19.13
// Cannot install pip dependencies without Python installed in the environment!
